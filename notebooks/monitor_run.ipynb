# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# run_path = "/home/raphael/Work/aida_ugent/dlp_viz/models/wikipedia/3"
run_path = "models/enron/4/"

logs = np.load(run_path + "/logs.npy", allow_pickle=True)[()]
logs = pd.DataFrame(logs).T


plt.plot(logs["train_loss"])
print(logs.columns)
# Out:
# Index(['auc_vs_destination', 'ap_vs_destination', 'auc_vs_historical_edge',
#        'ap_vs_historical_edge', 'auc_vs_inductive_edge',
#        'ap_vs_inductive_edge', 'auc_vs_inductive_dst', 'ap_vs_inductive_dst',
#        'auc_vs_historical_dst', 'ap_vs_historical_dst', 'train_loss'],
#       dtype='object')

# %%
# plt.plot(logs["auc_vs_historical_edge"])
for col in logs.columns:
    if "auc" in col:
        plt.plot(logs[col], label=col)

plt.legend(bbox_to_anchor=(1.05, 1), loc="upper left", borderaxespad=0.0)
